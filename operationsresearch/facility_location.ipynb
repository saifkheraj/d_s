# %%
import pandas as pd

# Function to clean and convert strings with commas into floats
def clean_numeric(value):
    if isinstance(value, str):
        try:
            return float(value.replace(',', ''))
        except ValueError:
            return value  # If it's not convertible, return as is (likely a customer name)
    return value

# Load CSV files into pandas dataframes
cost_to_host_engineer_location = pd.read_csv('input_files_parameters/cost_to_host_engineer_location.csv', skipinitialspace=True)
customer_location_reachability = pd.read_csv('input_files_parameters/customer_location_reachability.csv', skipinitialspace=True)
customer_service_required = pd.read_csv('input_files_parameters/customer_service_required.csv', skipinitialspace=True)
location_scale_rent = pd.read_csv('input_files_parameters/location_scale_rent.csv', skipinitialspace=True)
location_to_customer_cost = pd.read_csv('input_files_parameters/location_to_customer_cost.csv', skipinitialspace=True)
max_num_engineer_hosted = pd.read_csv('input_files_parameters/max_num_engineer_hosted.csv', skipinitialspace=True)

# Apply the cleaning function to numeric columns only
cost_to_host_engineer_location['Cost for Hosting One Engineer'] = cost_to_host_engineer_location['Cost for Hosting One Engineer'].apply(clean_numeric)
location_scale_rent['Rent'] = location_scale_rent['Rent'].apply(clean_numeric)
# Only apply cleaning to numeric columns, leaving customer names intact
numeric_cols = location_to_customer_cost.columns[1:]  # Skip the first column (Customer)
location_to_customer_cost[numeric_cols] = location_to_customer_cost[numeric_cols].applymap(clean_numeric)

# Constant: Number of services an engineer can complete per year
s = 200  # This is a simple average, adjust if needed for different engineer locations

# Display each dataframe to ensure they are loaded correctly
print("Cost to Host Engineer Location:\n", cost_to_host_engineer_location.head(), "\n")
print("Customer Location Reachability:\n", customer_location_reachability.head(), "\n")
print("Customer Service Required:\n", customer_service_required.head(), "\n")
print("Location Scale Rent:\n", location_scale_rent.head(), "\n")
print("Location to Customer Cost:\n", location_to_customer_cost.head(), "\n")
print("Max Number of Engineers Hosted:\n", max_num_engineer_hosted.head(), "\n")

# Convert each dataframe into a dictionary to use as parameters in the model

# 1. Cost to Host Engineer in each Location (c_j)
# c_j represents the annual cost for hosting one engineer at location j
c_j = dict(zip(cost_to_host_engineer_location['Location'], cost_to_host_engineer_location['Cost for Hosting One Engineer']))

# 2. Customer Location Reachability (a_ij)
# a_ij represents whether customer i can be served by facility j (1 if possible, 0 otherwise)
a_ij = customer_location_reachability.set_index('Customer').T.to_dict()

# 3. Customer Service Requirement (h_i)
# h_i represents the annual number of services required for customer i
h_i = dict(zip(customer_service_required['Customer'], customer_service_required['Annual # of Services Required']))

# 4. Location Scale Rent (f_jk)
# f_jk represents the annual office rent for facility j at scale k (small, medium, large)
f_jk = location_scale_rent.set_index(['Location', 'Scale'])['Rent'].to_dict()

# 5. Location to Customer Cost (d_ij)
# d_ij represents the cost per service for an engineer to travel between facility j and customer i
d_ij = location_to_customer_cost.set_index('Customer').T.to_dict()

# 6. Maximum Number of Engineers Hosted at a location (m_jk)
# m_jk represents the maximum number of engineers that can be hosted at location j with scale level k (small, medium, large)
m_jk = max_num_engineer_hosted.set_index('Location').T.to_dict()

# Display the dictionaries to verify they are correctly formatted
print("Cost to Host Engineer Dictionary (c_j):\n", c_j, "\n")
print("Reachability Dictionary (a_ij):\n", a_ij, "\n")
print("Customer Service Requirement Dictionary (h_i):\n", h_i, "\n")
print("Location Scale Rent Dictionary (f_jk):\n", f_jk, "\n")
print("Location to Customer Cost Dictionary (d_ij):\n", d_ij, "\n")
print("Max Number of Engineers Hosted Dictionary (m_jk):\n", m_jk, "\n")
# Out:
# Cost to Host Engineer Location:
#            Location  Cost for Hosting One Engineer
# 0         New York                       150000.0
# 1           Boston                       130000.0
# 2     Philadelphia                       120000.0
# 3  Washington D.C.                       140000.0
# 4        Baltimore                       110000.0
#
# Customer Location Reachability:
#    Customer  New York  Boston  Philadelphia  Washington D.C.  Baltimore  \
# 0    Cust1         1       1             0                1          0
# 1    Cust2         0       1             1                1          1
# 2    Cust3         1       1             1                1          1
# 3    Cust4         0       0             0                1          1
# 4    Cust5         1       1             0                1          0
#
#    Richmond  Virginia Beach  Charlotte  Raleigh  Atlanta  Nashville
# 0         0               0          1        0        1          0
# 1         0               0          0        1        1          0
# 2         1               0          0        0        1          0
# 3         1               1          1        0        1          1
# 4         0               0          1        0        1          1
#
# Customer Service Required:
#    Customer  Annual # of Services Required
# 0    Cust1                             15
# 1    Cust2                             20
# 2    Cust3                             10
# 3    Cust4                             25
# 4    Cust5                             18
#
# Location Scale Rent:
#     Location   Scale        Rent
# 0  New York   Small   5000000.0
# 1  New York  Medium   7500000.0
# 2  New York   Large  10000000.0
# 3    Boston   Small   1800000.0
# 4    Boston  Medium   2300000.0
#
# Location to Customer Cost:
#    Customer  New York  Boston  Philadelphia  Washington D.C.  Baltimore  \
# 0    Cust1       600     400           300              500        450
# 1    Cust2       700     350           250              600        500
# 2    Cust3       500     300           200              400        350
# 3    Cust4       800     450           350              700        600
# 4    Cust5       550     300           250              500        450
#
#    Richmond  Virginia Beach  Charlotte  Raleigh  Atlanta  Nashville
# 0       500             600        550      350      700        650
# 1       550             700        650      400      800        750
# 2       400             500        450      300      600        550
# 3       650             800        750      500      900        850
# 4       500             600        550      350      700        650
#
# Max Number of Engineers Hosted:
#            Location  Small  Medium  Large
# 0         New York     50     100    200
# 1           Boston     30      60    120
# 2     Philadelphia     25      50    100
# 3  Washington D.C.     40      80    160
# 4        Baltimore     20      40     80
#
# Cost to Host Engineer Dictionary (c_j):
#  {'New York': 150000.0, 'Boston': 130000.0, 'Philadelphia': 120000.0, 'Washington D.C.': 140000.0, 'Baltimore': 110000.0, 'Richmond': 100000.0, 'Virginia Beach': 95000.0, 'Charlotte': 110000.0, 'Raleigh': 105000.0, 'Atlanta': 120000.0, 'Nashville': 115000.0}
#
# Reachability Dictionary (a_ij):
#  {'Cust1': {'New York': 1, 'Boston': 1, 'Philadelphia': 0, 'Washington D.C.': 1, 'Baltimore': 0, 'Richmond': 0, 'Virginia Beach': 0, 'Charlotte': 1, 'Raleigh': 0, 'Atlanta': 1, 'Nashville': 0}, 'Cust2': {'New York': 0, 'Boston': 1, 'Philadelphia': 1, 'Washington D.C.': 1, 'Baltimore': 1, 'Richmond': 0, 'Virginia Beach': 0, 'Charlotte': 0, 'Raleigh': 1, 'Atlanta': 1, 'Nashville': 0}, 'Cust3': {'New York': 1, 'Boston': 1, 'Philadelphia': 1, 'Washington D.C.': 1, 'Baltimore': 1, 'Richmond':
FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   location_to_customer_cost[numeric_cols] = location_to_customer_cost[numeric_cols].applymap(clean_numeric)

# %%
import pulp

# %%
# Binary decision variable y_ij: 1 if customer i is served by facility j, 0 otherwise
# Since a_ij is a nested dictionary, we iterate over the customers and locations within a_ij

# %%
#y_ij

# %%
import pulp

# Step 1: Initialize the LP problem
problem = pulp.LpProblem("Facility_Location_Problem", pulp.LpMinimize)

# Step 2: Define Decision Variables
# Binary decision variable x_jk: 1 if a facility j is built at scale k, 0 otherwise
x_jk = pulp.LpVariable.dicts("x_jk", ((loc, scale) for loc, scale in f_jk), cat='Binary')

# Binary decision variable y_ij: 1 if customer i is served by facility j, 0 otherwise
y_ij = pulp.LpVariable.dicts("y_ij", ((cust, loc) for cust in a_ij for loc in a_ij[cust]), cat='Binary')

# Engineer hosting variable w_j (number of engineers assigned to location j)
w_j = pulp.LpVariable.dicts("w_j", (loc for loc in c_j), lowBound=0, cat='Integer')

# Step 3: Define the Objective Function (Minimize total cost)
# Objective function is the sum of office rent, traveling cost, and engineer hosting cost

# 1. Office rent cost: sum(f_jk * x_jk)
office_rent_cost = pulp.lpSum([x_jk[(loc, scale)] * f_jk[(loc, scale)] for loc, scale in f_jk])

# 2. Traveling cost: sum(h_i * d_ij * y_ij)
traveling_cost = pulp.lpSum([h_i[cust] * d_ij[cust][loc] * y_ij[(cust, loc)] 
                             for cust in h_i for loc in d_ij[cust]])

# 3. Engineer hosting cost: sum(c_j * w_j)
engineer_hosting_cost = pulp.lpSum([c_j[loc] * w_j[loc] for loc in c_j])

# Total cost (objective function)
total_cost = office_rent_cost + traveling_cost + engineer_hosting_cost

# Add the objective function to the problem
problem += total_cost, "Minimize Total Cost"

# You can now add constraints (if any) and solve the problem

# %%
#x_jk

# %%
# Add the constraints to the problem

# Constraint 1: At most one scale level for each location
for loc in c_j:
    problem += pulp.lpSum([x_jk[(loc, scale)] for scale in ['Small', 'Medium', 'Large']]) == 1, f"Max_One_Scale_{loc}"

# Constraint 2: Only a built facility may serve customers
for cust in h_i:
    for loc in a_ij[cust]:
        problem += y_ij[(cust, loc)] <= pulp.lpSum([x_jk[(loc, scale)] for scale in ['Small', 'Medium', 'Large']]), f"Serve_Only_Built_{cust}_{loc}"

# Constraint 3: Each customer must be served by one facility
for cust in h_i:
    problem += pulp.lpSum([a_ij[cust][loc] * y_ij[(cust, loc)] for loc in a_ij[cust]]) == 1, f"Serve_Customer_{cust}"

# Ensures that the number of engineers allocated to a facility does not exceed its capacity based on the chosen scale.
for loc in m_jk:
    problem += w_j[loc] <= pulp.lpSum([m_jk[loc][scale] * x_jk[(loc, scale)] for scale in ['Small', 'Medium', 'Large']]), f"Capacity_Constraint_{loc}"

# Ensures that the allocated engineers can fulfill the service demands assigned to a facility.
for loc in c_j:
    problem += s * w_j[loc] >= pulp.lpSum([h_i[cust] * y_ij[(cust, loc)] for cust in h_i]), f"Service_Requirement_Constraint_{loc}"

# %%
m_jk['New York']['Small']
# Out:
# 50

# %%
# Solve the problem
problem.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/codespace/.python/current/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9d591fb8642248f796f512add81614ad-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/9d591fb8642248f796f512add81614ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 638 COLUMNS
# At line 5592 RHS
# At line 6226 BOUNDS
# At line 6821 ENDATA
# Problem MODEL has 633 rows, 594 columns and 3171 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.88876e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 26 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 416 rows, 377 columns (377 integer (366 of which binary)) and 2086 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.1
# Cbc0038I Solution found of 1.88876e+07
# Cbc0038I Branch and bound needed to clear up 4 general integers
# Cbc0038I Full problem 416 rows 377 columns, reduced to 0 rows 0 columns
# Cbc0038I Cleaned solution of 1.91298e+07
# Cbc0038I Before mini branch and bound, 373 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 416 rows 377 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 1.91056e+07
# Cbc0038I Reduced cost fixing fixed 22 variables on major pass 2
# Cbc0038I Solution found of 1.88876e+07
# Cbc0038I Branch and bound needed to clear up 4 general integers
# Cbc0038I Mini branch and bound could not fix general integers
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 373 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 416 rows 377 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 1.91298e+07 - took 0.00 seconds
# Cbc0012I Integer solution of 19129800 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0012I Integer solution of 19013700 found by DiveCoefficient after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 416 rows 377 columns, reduced to 1 rows 3 columns
# Cbc0031I 37 added rows had average density of 66.702703
# Cbc0013I At root node, 37 cuts changed objective from 18887650 to 18906327 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 597 row cuts average 2.0 elements, 1 column cuts (3 active)  in 0.312 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1494 row cuts average 340.5 elements, 0 column cuts (0 active)  in 0.171 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 522 row cuts average 18.0 elements, 0 column cuts (0 active)  in 0.050 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 301 row cuts average 73.6 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 19013700 best solution, best possible 18906327 (1.06 seconds)
# Cbc0012I Integer solution of 18933100 found by DiveCoefficient after 6112 iterations and 4 nodes (1.13 seconds)
# Cbc0012I Integer solution of 18933000 found by DiveCoefficient after 6123 iterations and 4 nodes (1.14 seconds)
# Cbc0012I Integer solution of 18930750 found by DiveCoefficient after 6267 iterations and 8 nodes (1.15 seconds)
# Cbc0012I Integer solution of 18930000 found by DiveCoefficient after 6268 iterations and 9 nodes (1.16 seconds)
# Cbc0012I Integer solution of 18929650 found by DiveCoefficient after 6329 iterations and 22 nodes (1.18 seconds)
# Cbc0016I Integer solution of 18929450 found by strong branching after 6335 iterations and 22 nodes (1.18 seconds)
# Cbc0038I Full problem 416 rows 377 columns, reduced to 3 rows 6 columns
# Cbc0012I Integer solution of 18920250 found by DiveCoefficient after 7453 iterations and 85 nodes (1.33 seconds)
# Cbc0038I Full problem 416 rows 377 columns, reduced to 4 rows 18 columns
# Cbc0004I Integer solution of 18909700 found after 7770 iterations and 105 nodes (1.37 seconds)
# Cbc0016I Integer solution of 18909550 found by strong branching after 7910 iterations and 115 nodes (1.37 seconds)
# Cbc0016I Integer solution of 18909450 found by strong branching after 7940 iterations and 122 nodes (1.38 seconds)
# Cbc0001I Search completed - best objective 18909450, took 8266 iterations and 129 nodes (1.38 seconds)
# Cbc0032I Strong branching done 1088 times (11913 iterations), fathomed 30 nodes and fixed 28 variables
# Cbc0035I Maximum depth 18, 816 variables fixed on reduced cost
# Cuts at root node changed objective from 1.88876e+07 to 1.89063e+07
# Probing was tried 168 times and created 734 cuts of which 2 were active after adding rounds of cuts (0.322 seconds)
# Gomory was tried 167 times and created 1497 cuts of which 0 were active after adding rounds of cuts (0.183 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 167 times and created 695 cuts of which 0 were active after adding rounds of cuts (0.063 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# TwoMirCuts was tried 100 times and created 301 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                18909450.00000000
# Enumerated nodes:               129
# Total iterations:               8266
# Time (CPU seconds):             1.37
# Time (Wallclock seconds):       1.41
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.37   (Wallclock seconds):       1.41
# 1

# %%
x_jk[('New York','Small')].varValue
# Out:
# 0.0

# %%
import pandas as pd

# List to store results for each location
results = []

# Loop over each location and gather data
for loc in w_j:
    engineers_allocated = int(w_j[loc].varValue) if w_j[loc].varValue is not None else 0
    customers_assigned = sum([y_ij[(cust, loc)].varValue for cust in h_i if (cust, loc) in y_ij])
    services_assigned = sum([h_i[cust] * y_ij[(cust, loc)].varValue for cust in h_i if (cust, loc) in y_ij])

    # Find the chosen scale for each location
    chosen_scale = "None"  # Default value
    for scale in ['Small', 'Medium', 'Large']:
        if (loc, scale) in x_jk and x_jk[(loc, scale)].varValue == 1:
            chosen_scale = scale.capitalize()
            break
    
    # Append results to the list
    results.append([loc, chosen_scale, engineers_allocated, int(customers_assigned), int(services_assigned)])

# Convert results to DataFrame
results_df = pd.DataFrame(results, columns=["Location", "Scale", "Engineers Allocated", "Customers Assigned", "Services Assigned"])

# Calculate totals and create a DataFrame for the totals row
totals = pd.DataFrame({
    "Location": ["Total"],
    "Scale": [f"Large {sum(results_df['Scale'] == 'Large')}, Small {sum(results_df['Scale'] == 'Small')}"],
    "Engineers Allocated": [results_df["Engineers Allocated"].sum()],
    "Customers Assigned": [results_df["Customers Assigned"].sum()],
    "Services Assigned": [results_df["Services Assigned"].sum()]
})

# Concatenate the totals row with the original DataFrame
results_df = pd.concat([results_df, totals], ignore_index=True)

# Print the results in table form
print(results_df)
# Out:
#            Location              Scale  Engineers Allocated  \
# 0          New York              Small                    0
# 1            Boston              Small                    1
# 2      Philadelphia              Small                    3
# 3   Washington D.C.              Small                    0
# 4         Baltimore              Small                    0
# 5          Richmond              Small                    1
# 6    Virginia Beach              Small                    0
# 7         Charlotte              Small                    0
# 8           Raleigh              Small                    0
# 9           Atlanta              Small                    0
# 10        Nashville              Small                    0
# 11            Total  Large 0, Small 11                    5
#
#     Customers Assigned  Services Assigned
# 0                    0                  0
# 1                   12                198
# 2                   30                598
# 3                    0                  0
# 4                    0                  0
# 5                    8                174
# 6                    0                  0
# 7                    0                  0
# 8                    0                  0
# 9                    0                  0
# 10                   0                  0
# 11                  50                970

# %%
# 2. Traveling cost: sum(h_i * d_ij * y_ij)
traveling_cost = pulp.lpSum([h_i[cust] * d_ij[cust][loc] * y_ij[(cust, loc)] 
                             for cust in h_i for loc in d_ij[cust]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 2. Traveling cost: sum(h_i * d_ij * y_ij)
# ----> 2 traveling_cost = pulp.lpSum([h_i[cust] * d_ij[cust][loc] * y_ij[(cust, loc)]
#       3                              for cust in h_i for loc in d_ij[cust]])
#
# KeyError: ('Cust1', 'New York')

# %%
y_ij
# Out:
# {('Cust1', 'Cust1'): y_ij_('Cust1',_'Cust1'),
#  ('Cust1', 'Cust2'): y_ij_('Cust1',_'Cust2'),
#  ('Cust1', 'Cust3'): y_ij_('Cust1',_'Cust3'),
#  ('Cust1', 'Cust4'): y_ij_('Cust1',_'Cust4'),
#  ('Cust1', 'Cust5'): y_ij_('Cust1',_'Cust5'),
#  ('Cust1', 'Cust6'): y_ij_('Cust1',_'Cust6'),
#  ('Cust1', 'Cust7'): y_ij_('Cust1',_'Cust7'),
#  ('Cust1', 'Cust8'): y_ij_('Cust1',_'Cust8'),
#  ('Cust1', 'Cust9'): y_ij_('Cust1',_'Cust9'),
#  ('Cust1', 'Cust10'): y_ij_('Cust1',_'Cust10'),
#  ('Cust1', 'Cust11'): y_ij_('Cust1',_'Cust11'),
#  ('Cust1', 'Cust12'): y_ij_('Cust1',_'Cust12'),
#  ('Cust1', 'Cust13'): y_ij_('Cust1',_'Cust13'),
#  ('Cust1', 'Cust14'): y_ij_('Cust1',_'Cust14'),
#  ('Cust1', 'Cust15'): y_ij_('Cust1',_'Cust15'),
#  ('Cust1', 'Cust16'): y_ij_('Cust1',_'Cust16'),
#  ('Cust1', 'Cust17'): y_ij_('Cust1',_'Cust17'),
#  ('Cust1', 'Cust18'): y_ij_('Cust1',_'Cust18'),
#  ('Cust1', 'Cust19'): y_ij_('Cust1',_'Cust19'),
#  ('Cust1', 'Cust20'): y_ij_('Cust1',_'Cust20'),
#  ('Cust1', 'Cust21'): y_ij_('Cust1',_'Cust21'),
#  ('Cust1', 'Cust22'): y_ij_('Cust1',_'Cust22'),
#  ('Cust1', 'Cust23'): y_ij_('Cust1',_'Cust23'),
#  ('Cust1', 'Cust24'): y_ij_('Cust1',_'Cust24'),
#  ('Cust1', 'Cust25'): y_ij_('Cust1',_'Cust25'),
#  ('Cust1', 'Cust26'): y_ij_('Cust1',_'Cust26'),
#  ('Cust1', 'Cust27'): y_ij_('Cust1',_'Cust27'),
#  ('Cust1', 'Cust28'): y_ij_('Cust1',_'Cust28'),
#  ('Cust1', 'Cust29'): y_ij_('Cust1',_'Cust29'),
#  ('Cust1', 'Cust30'): y_ij_('Cust1',_'Cust30'),
#  ('Cust1', 'Cust31'): y_ij_('Cust1',_'Cust31'),
#  ('Cust1', 'Cust32'): y_ij_('Cust1',_'Cust32'),
#  ('Cust1', 'Cust33'): y_ij_('Cust1',_'Cust33'),
#  ('Cust1', 'Cust34'): y_ij_('Cust1',_'Cust34'),
#  ('Cust1', 'Cust35'): y_ij_('Cust1',_'Cust35'),
#  ('Cust1', 'Cust36'): y_ij_('Cust1',_'Cust36'),
#  ('Cust1', 'Cust37'): y_ij_('Cust1',_'Cust37'),
#  ('Cust1', 'Cust38'): y_ij_('Cust1',_'Cust38'),
#  ('Cust1', 'Cust39'): y_ij_('Cust1',_'Cust39'),
#  ('Cust1', 'Cust40'): y_ij_('Cust1',_'Cust40'),
#  ('Cust1', 'Cust41'): y_ij_('Cust1',_'Cust41'),
#  ('Cust1', 'Cust42'): y_ij_('Cust1',_'Cust42'),
#  ('Cust1', 'Cust43'): y_ij_('Cust1',_'Cust43'),
#  ('Cust1', 'Cust44'): y_ij_('Cust1',_'Cust44'),
#  ('Cust3', 'Cust28'): y_ij_('Cust3',_'Cust28'),
#  ('Cust3', 'Cust29'): y_ij_('Cust3',_'Cust29'),
#  ('Cust3', 'Cust30'): y_ij_('Cust3',_'Cust30'),
#  ('Cust3', 'Cust31'): y_ij_('Cust3',_'Cust31'),
#  ('Cust3', 'Cust32'): y_ij_('Cust3',_'Cust32'),
#  ('Cust3', 'Cust33'): y_ij_('Cust3',_'Cust33'),
#  ('Cust3', 'Cust34'): y_ij_('Cust3',_'Cust34'),
#  ('Cust3', 'Cust35'): y_ij_('Cust3',_'Cust35'),
#  ('Cust3', 'Cust36'): y_ij_('Cust3',_'Cust36'),
#  ('Cust3', 'Cust37'): y_ij_('Cust3',_'Cust37'),
#  ('Cust3', 'Cust38'): y_ij_('Cust3',_'Cust38'),
#  ('Cust3', 'Cust39'): y_ij_('Cust3',_'Cust39'),
#  ('Cust3', 'Cust40'): y_ij_('Cust3',_'Cust40'),
#  ('Cust3', 'Cust41'): y_ij_('Cust3',_'Cust41'),
#  ('Cust3', 'Cust42'): y_ij_('Cust3',_'Cust42'),
#  ('Cust3', 'Cust43'): y_ij_('Cust3',_'Cust43'),
#  ('Cust3', 'Cust44'): y_ij_('Cust3',_'Cust44'),
#  ('Cust3', 'Cust45'): y_ij_('Cust3',_'Cust45'),
#  ('Cust3', 'Cust46'): y_ij_('Cust3',_'Cust46'),
#  ('Cust3', 'Cust47'): y_ij_('Cust3',_'Cust47'),
#  ('Cust3', 'Cust48'): y_ij_('Cust3',_'Cust48'),
#  ('Cust3', 'Cust49'): y_ij_('Cust3',_'Cust49'),
#  ('Cust3', 'Cust50'): y_ij_('Cust3',_'Cust50'),
#  ('Cust4', 'Cust1'): y_ij_('Cust4',_'Cust1'),
#  ('Cust4', 'Cust2'): y_ij_('Cust4',_'Cust2'),
#  ('Cust4', 'Cust3'): y_ij_('Cust4',_'Cust3'),
#  ('Cust4', 'Cust4'): y_ij_('Cust4',_'Cust4'),
#  ('Cust4', 'Cust5'): y_ij_('Cust4',_'Cust5'),
#  ('Cust4', 'Cust6'): y_ij_('Cust4',_'Cust6'),
#  ('Cust4', 'Cust7'): y_ij_('Cust4',_'Cust7'),
#  ('Cust4', 'Cust8'): y_ij_('Cust4',_'Cust8'),
#  ('Cust4', 'Cust9'): y_ij_('Cust4',_'Cust9'),
#  ('Cust4', 'Cust10'): y_ij_('Cust4',_'Cust10'),
#  ('Cust4', 'Cust11'): y_ij_('Cust4',_'Cust11'),
#  ('Cust4', 'Cust12'): y_ij_('Cust4',_'Cust12'),
#  ('Cust4', 'Cust13'): y_ij_('Cust4',_'Cust13'),
#  ('Cust4', 'Cust14'): y_ij_('Cust4',_'Cust14'),
#  ('Cust4', 'Cust15'): y_ij_('Cust4',_'Cust15'),
#  ('Cust4', 'Cust16'): y_ij_('Cust4',_'Cust16'),
#  ('Cust4', 'Cust17'): y_ij_('Cust4',_'Cust17'),
#  ('Cust4', 'Cust18'): y_ij_('Cust4',_'Cust18'),
#  ('Cust4', 'Cust19'): y_ij_('Cust4',_'Cust19'),
#  ('Cust4', 'Cust20'): y_ij_('Cust4',_'Cust20'),
#  ('Cust4', 'Cust21'): y_ij_('Cust4',_'Cust21'),
#  ('Cust4', 'Cust22'): y_ij_('Cust4',_'Cust22'),
#  ('Cust4', 'Cust23'): y_ij_('Cust4',_'Cust23'),
#  ('Cust4', 'Cust24'): y_ij_('Cust4',_'Cust24'),
#  ('Cust4', 'Cust25'): y_ij_('Cust4',_'Cust25'),
#  ('Cust4', 'Cust26'): y_ij_('Cust4',_'Cust26'),
#  ('Cust4', 'Cust27'): y_ij_('Cust4',_'Cust27'),
#  ('Cust4', 'Cust28'): y_ij_('Cust4',_'Cust28'),
#  ('Cust4', 'Cust29'): y_ij_('Cust4',_'Cust29'),
#  ('Cust4', 'Cust30'): y_ij_('Cust4',_'Cust30'),
#  ('Cust4', 'Cust31'): y_ij_('Cust4',_'Cust31'),
#  ('Cust4', 'Cust32'): y_ij_('Cust4',_'Cust32'),
#  ('Cust4', 'Cust33'): y_ij_('Cust4',_'Cust33'),
#  ('Cust4', 'Cust34'): y_ij_('Cust4',_'Cust34'),
#  ('Cust4', 'Cust35'): y_ij_('Cust4',_'Cust35'),
#  ('Cust4', 'Cust36'): y_ij_('Cust4',_'Cust36'),
#  ('Cust4', 'Cust37'): y_ij_('Cust4',_'Cust37'),
#  ('Cust4', 'Cust38'): y_ij_('Cust4',_'Cust38'),
#  ('Cust4', 'Cust39'): y_ij_('Cust4',_'Cust39'),
#  ('Cust4', 'Cust40'): y_ij_('Cust4',_'Cust40'),
#  ('Cust4', 'Cust41'): y_ij_('Cust4',_'Cust41'),
#  ('Cust4', 'Cust42'): y_ij_('Cust4',_'Cust42'),
#  ('Cust4', 'Cust43'): y_ij_('Cust4',_'Cust43'),
#  ('Cust4', 'Cust44'): y_ij_('Cust4',_'Cust44'),
#  ('Cust4', 'Cust45'): y_ij_('Cust4',_'Cust45'),
#  ('Cust4', 'Cust46'): y_ij_('Cust4',_'Cust46'),
#  ('Cust4', 'Cust47'): y_ij_('Cust4',_'Cust47'),
#  ('Cust4', 'Cust48'): y_ij_('Cust4',_'Cust48'),
#  ('Cust4', 'Cust49'): y_ij_('Cust4',_'Cust49'),
#  ('Cust4', 'Cust50'): y_ij_('Cust4',_'Cust50'),
#  ('Cust5', 'Cust1'): y_ij_('Cust5',_'Cust1'),
#  ('Cust5', 'Cust2'): y_ij_('Cust5',_'Cust2'),
#  ('Cust5', 'Cust3'): y_ij_('Cust5',_'Cust3'),
#  ('Cust5', 'Cust4'): y_ij_('Cust5',_'Cust4'),
#  ('Cust5', 'Cust5'): y_ij_('Cust5',_'Cust5'),
#  ('Cust5', 'Cust6'): y_ij_('Cust5',_'Cust6'),
#  ('Cust5', 'Cust7'): y_ij_('Cust5',_'Cust7'),
#  ('Cust5', 'Cust8'): y_ij_('Cust5',_'Cust8'),
#  ('Cust5', 'Cust9'): y_ij_('Cust5',_'Cust9'),
#  ('Cust5', 'Cust10'): y_ij_('Cust5',_'Cust10'),
#  ('Cust5', 'Cust11'): y_ij_('Cust5',_'Cust11'),
#  ('Cust5', 'Cust12'): y_ij_('Cust5',_'Cust12'),
#  ('Cust5', 'Cust13'): y_ij_('Cust5',_'Cust13'),
#  ('Cust5', 'Cust14'): y_ij_('Cust5',_'Cust14'),
#  ('Cust5', 'Cust15'): y_ij_('Cust5',_'Cust15'),
#  ('Cust5', 'Cust16'): y_ij_('Cust5',_'Cust16'),
#  ('Cust5', 'Cust17'): y_ij_('Cust5',_'Cust17'),
#  ('Cust5', 'Cust18'): y_ij_('Cust5',_'Cust18'),
#  ('Cust5', 'Cust19'): y_ij_('Cust5',_'Cust19'),
#  ('Cust5', 'Cust20'): y_ij_('Cust5',_'Cust20'),
#  ('Cust5', 'Cust21'): y_ij_('Cust5',_'Cust21'),
#  ('Cust5', 'Cust22'): y_ij_('Cust5',_'Cust22'),
#  ('Cust5', 'Cust23'): y_ij_('Cust5',_'Cust23'),
#  ('Cust5', 'Cust24'): y_ij_('Cust5',_'Cust24'),
#  ('Cust5', 'Cust25'): y_ij_('Cust5',_'Cust25'),
#  ('Cust5', 'Cust26'): y_ij_('Cust5',_'Cust26'),
#  ('Cust5', 'Cust27'): y_ij_('Cust5',_'Cust27'),
#  ('Cust5', 'Cust28'): y_ij_('Cust5',_'Cust28'),
#  ('Cust5', 'Cust29'): y_ij_('Cust5',_'Cust29'),
#  ('Cust5', 'Cust30'): y_ij_('Cust5',_'Cust30'),
#  ('Cust5', 'Cust31'): y_ij_('Cust5',_'Cust31'),
#  ('Cust5', 'Cust32'): y_ij_('Cust5',_'Cust32'),
#  ('Cust5', 'Cust33'): y_ij_('Cust5',_'Cust33'),
#  ('Cust5', 'Cust34'): y_ij_('Cust5',_'Cust34'),
#  ('Cust5', 'Cust35'): y_ij_('Cust5',_'Cust35'),
#  ('Cust5', 'Cust36'): y_ij_('Cust5',_'Cust36'),
#  ('Cust5', 'Cust37'): y_ij_('Cust5',_'Cust37'),
#  ('Cust5', 'Cust38'): y_ij_('Cust5',_'Cust38'),
#  ('Cust5', 'Cust39'): y_ij_('Cust5',_'Cust39'),
#  ('Cust5', 'Cust40'): y_ij_('Cust5',_'Cust40'),
#  ('Cust5', 'Cust41'): y_ij_('Cust5',_'Cust41'),
#  ('Cust5', 'Cust42'): y_ij_('Cust5',_'Cust42'),
#  ('Cust5', 'Cust43'): y_ij_('Cust5',_'Cust43'),
#  ('Cust5', 'Cust44'): y_ij_('Cust5',_'Cust44'),
#  ('Cust5', 'Cust45'): y_ij_('Cust5',_'Cust45'),
#  ('Cust5', 'Cust46'): y_ij_('Cust5',_'Cust46'),
#  ('Cust5', 'Cust47'): y_ij_('Cust5',_'Cust47'),
#  ('Cust5', 'Cust48'): y_ij_('Cust5',_'Cust48'),
#  ('Cust5', 'Cust49'): y_ij_('Cust5',_'Cust49'),
#  ('Cust5', 'Cust50'): y_ij_('Cust5',_'Cust50'),
#  ('Cust6', 'Cust1'): y_ij_('Cust6',_'Cust1'),
#  ('Cust6', 'Cust2'): y_ij_('Cust6',_'Cust2'),
#  ('Cust6', 'Cust3'): y_ij_('Cust6',_'Cust3'),
#  ('Cust6', 'Cust4'): y_ij_('Cust6',_'Cust4'),
#  ('Cust6', 'Cust5'): y_ij_('Cust6',_'Cust5'),
#  ('Cust6', 'Cust6'): y_ij_('Cust6',_'Cust6'),
#  ('Cust6', 'Cust7'): y_ij_('Cust6',_'Cust7'),
#  ('Cust6', 'Cust8'): y_ij_('Cust6',_'Cust8'),
#  ('Cust6', 'Cust9'): y_ij_('Cust6',_'Cust9'),
#  ('Cust6', 'Cust10'): y_ij_('Cust6',_'Cust10'),
#  ('Cust6', 'Cust11'): y_ij_('Cust6',_'Cust11'),
#  ('Cust6', 'Cust12'): y_ij_('Cust6',_'Cust12'),
#  ('Cust6', 'Cust13'): y_ij_('Cust6',_'Cust13'),
#  ('Cust6', 'Cust14'): y_ij_('Cust6',_'Cust14'),
#  ('Cust6', 'Cust15'): y_ij_('Cust6',_'Cust15'),
#  ('Cust6', 'Cust16'): y_ij_('Cust6',_'Cust16'),
#  ('Cust6', 'Cust17'): y_ij_('Cust6',_'Cust17'),
#  ('Cust6', 'Cust18'): y_ij_('Cust6',_'Cust18'),
#  ('Cust6', 'Cust19'): y_ij_('Cust6',_'Cust19'),
#  ('Cust6', 'Cust20'): y_ij_('Cust6',_'Cust20'),
#  ('Cust6', 'Cust21'): y_ij_('Cust6',_'Cust21'),
#  ('Cust6', 'Cust22'): y_ij_('Cust6',_'Cust22'),
#  ('Cust6', 'Cust23'): y_ij_('Cust6',_'Cust23'),
#  ('Cust6', 'Cust24'): y_ij_('Cust6',_'Cust24'),
#  ('Cust6', 'Cust25'): y_ij_('Cust6',_'Cust25'),
#  ('Cust6', 'Cust26'): y_ij_('Cust6',_'Cust26'),
#  ('Cust6', 'Cust27'): y_ij_('Cust6',_'Cust27'),
#  ('Cust6', 'Cust28'): y_ij_('Cust6',_'Cust28'),
#  ('Cust6', 'Cust29'): y_ij_('Cust6',_'Cust29'),
#  ('Cust6', 'Cust30'): y_ij_('Cust6',_'Cust30'),
#  ('Cust6', 'Cust31'): y_ij_('Cust6',_'Cust31'),
#  ('Cust6', 'Cust32'): y_ij_('Cust6',_'Cust32'),
#  ('Cust6', 'Cust33'): y_ij_('Cust6',_'Cust33'),
#  ('Cust6', 'Cust34'): y_ij_('Cust6',_'Cust34'),
#  ('Cust6', 'Cust35'): y_ij_('Cust6',_'Cust35'),
#  ('Cust6', 'Cust36'): y_ij_('Cust6',_'Cust36'),
#  ('Cust6', 'Cust37'): y_ij_('Cust6',_'Cust37'),
#  ('Cust6', 'Cust38'): y_ij_('Cust6',_'Cust38'),
#  ('Cust6', 'Cust39'): y_ij_('Cust6',_'Cust39'),
#  ('Cust6', 'Cust40'): y_ij_('Cust6',_'Cust40'),
#  ('Cust6', 'Cust41'): y_ij_('Cust6',_'Cust41'),
#  ('Cust6', 'Cust42'): y_ij_('Cust6',_'Cust42'),
#  ('Cust6', 'Cust43'): y_ij_('Cust6',_'Cust43'),
#  ('Cust8', 'Cust28'): y_ij_('Cust8',_'Cust28'),
#  ('Cust8', 'Cust29'): y_ij_('Cust8',_'Cust29'),
#  ('Cust8', 'Cust30'): y_ij_('Cust8',_'Cust30'),
#  ('Cust8', 'Cust31'): y_ij_('Cust8',_'Cust31'),
#  ('Cust8', 'Cust32'): y_ij_('Cust8',_'Cust32'),
#  ('Cust8', 'Cust33'): y_ij_('Cust8',_'Cust33'),
#  ('Cust8', 'Cust34'): y_ij_('Cust8',_'Cust34'),
#  ('Cust8', 'Cust35'): y_ij_('Cust8',_'Cust35'),
#  ('Cust8', 'Cust36'): y_ij_('Cust8',_'Cust36'),
#  ('Cust8', 'Cust37'): y_ij_('Cust8',_'Cust37'),
#  ('Cust8', 'Cust38'): y_ij_('Cust8',_'Cust38'),
#  ('Cust8', 'Cust39'): y_ij_('Cust8',_'Cust39'),
#  ('Cust8', 'Cust40'): y_ij_('Cust8',_'Cust40'),
#  ('Cust8', 'Cust41'): y_ij_('Cust8',_'Cust41'),
#  ('Cust8', 'Cust42'): y_ij_('Cust8',_'Cust42'),
#  ('Cust8', 'Cust43'): y_ij_('Cust8',_'Cust43'),
#  ('Cust8', 'Cust44'): y_ij_('Cust8',_'Cust44'),
#  ('Cust8', 'Cust45'): y_ij_('Cust8',_'Cust45'),
#  ('Cust8', 'Cust46'): y_ij_('Cust8',_'Cust46'),
#  ('Cust8', 'Cust47'): y_ij_('Cust8',_'Cust47'),
#  ('Cust8', 'Cust48'): y_ij_('Cust8',_'Cust48'),
#  ('Cust8', 'Cust49'): y_ij_('Cust8',_'Cust49'),
#  ('Cust8', 'Cust50'): y_ij_('Cust8',_'Cust50'),
#  ('Cust9', 'Cust1'): y_ij_('Cust9',_'Cust1'),
#  ('Cust9', 'Cust2'): y_ij_('Cust9',_'Cust2'),
#  ('Cust9', 'Cust3'): y_ij_('Cust9',_'Cust3'),
#  ('Cust9', 'Cust4'): y_ij_('Cust9',_'Cust4'),
#  ('Cust9', 'Cust5'): y_ij_('Cust9',_'Cust5'),
#  ('Cust9', 'Cust6'): y_ij_('Cust9',_'Cust6'),
#  ('Cust9', 'Cust7'): y_ij_('Cust9',_'Cust7'),
#  ('Cust9', 'Cust8'): y_ij_('Cust9',_'Cust8'),
#  ('Cust9', 'Cust9'): y_ij_('Cust9',_'Cust9'),
#  ('Cust9', 'Cust10'): y_ij_('Cust9',_'Cust10'),
#  ('Cust9', 'Cust11'): y_ij_('Cust9',_'Cust11'),
#  ('Cust9', 'Cust12'): y_ij_('Cust9',_'Cust12'),
#  ('Cust9', 'Cust13'): y_ij_('Cust9',_'Cust13'),
#  ('Cust9', 'Cust14'): y_ij_('Cust9',_'Cust14'),
#  ('Cust9', 'Cust15'): y_ij_('Cust9',_'Cust15'),
#  ('Cust9', 'Cust16'): y_ij_('Cust9',_'Cust16'),
#  ('Cust9', 'Cust17'): y_ij_('Cust9',_'Cust17'),
#  ('Cust9', 'Cust18'): y_ij_('Cust9',_'Cust18'),
#  ('Cust9', 'Cust19'): y_ij_('Cust9',_'Cust19'),
#  ('Cust9', 'Cust20'): y_ij_('Cust9',_'Cust20'),
#  ('Cust9', 'Cust21'): y_ij_('Cust9',_'Cust21'),
#  ('Cust9', 'Cust22'): y_ij_('Cust9',_'Cust22'),
#  ('Cust9', 'Cust23'): y_ij_('Cust9',_'Cust23'),
#  ('Cust9', 'Cust24'): y_ij_('Cust9',_'Cust24'),
#  ('Cust9', 'Cust25'): y_ij_('Cust9',_'Cust25'),
#  ('Cust9', 'Cust26'): y_ij_('Cust9',_'Cust26'),
#  ('Cust9', 'Cust27'): y_ij_('Cust9',_'Cust27'),
#  ('Cust9', 'Cust28'): y_ij_('Cust9',_'Cust28'),
#  ('Cust9', 'Cust29'): y_ij_('Cust9',_'Cust29'),
#  ('Cust9', 'Cust30'): y_ij_('Cust9',_'Cust30'),
#  ('Cust9', 'Cust31'): y_ij_('Cust9',_'Cust31'),
#  ('Cust9', 'Cust32'): y_ij_('Cust9',_'Cust32'),
#  ('Cust9', 'Cust33'): y_ij_('Cust9',_'Cust33'),
#  ('Cust9', 'Cust34'): y_ij_('Cust9',_'Cust34'),
#  ('Cust9', 'Cust35'): y_ij_('Cust9',_'Cust35'),
#  ('Cust9', 'Cust36'): y_ij_('Cust9',_'Cust36'),
#  ('Cust9', 'Cust37'): y_ij_('Cust9',_'Cust37'),
#  ('Cust9', 'Cust38'): y_ij_('Cust9',_'Cust38'),
#  ('Cust9', 'Cust39'): y_ij_('Cust9',_'Cust39'),
#  ('Cust9', 'Cust40'): y_ij_('Cust9',_'Cust40'),
#  ('Cust9', 'Cust41'): y_ij_('Cust9',_'Cust41'),
#  ('Cust9', 'Cust42'): y_ij_('Cust9',_'Cust42'),
#  ('Cust9', 'Cust43'): y_ij_('Cust9',_'Cust43'),
#  ('Cust9', 'Cust44'): y_ij_('Cust9',_'Cust44'),
#  ('Cust9', 'Cust45'): y_ij_('Cust9',_'Cust45'),
#  ('Cust9', 'Cust46'): y_ij_('Cust9',_'Cust46'),
#  ('Cust9', 'Cust47'): y_ij_('Cust9',_'Cust47'),
#  ('Cust9', 'Cust48'): y_ij_('Cust9',_'Cust48'),
#  ('Cust9', 'Cust49'): y_ij_('Cust9',_'Cust49'),
#  ('Cust9', 'Cust50'): y_ij_('Cust9',_'Cust50'),
#  ('Cust10', 'Cust1'): y_ij_('Cust10',_'Cust1'),
#  ('Cust10', 'Cust2'): y_ij_('Cust10',_'Cust2'),
#  ('Cust10', 'Cust3'): y_ij_('Cust10',_'Cust3'),
#  ('Cust10', 'Cust4'): y_ij_('Cust10',_'Cust4'),
#  ('Cust10', 'Cust5'): y_ij_('Cust10',_'Cust5'),
#  ('Cust10', 'Cust6'): y_ij_('Cust10',_'Cust6'),
#  ('Cust10', 'Cust7'): y_ij_('Cust10',_'Cust7'),
#  ('Cust10', 'Cust8'): y_ij_('Cust10',_'Cust8'),
#  ('Cust10', 'Cust9'): y_ij_('Cust10',_'Cust9'),
#  ('Cust10', 'Cust10'): y_ij_('Cust10',_'Cust10'),
#  ('Cust11', 'Cust44'): y_ij_('Cust11',_'Cust44'),
#  ('Cust11', 'Cust45'): y_ij_('Cust11',_'Cust45'),
#  ('Cust11', 'Cust46'): y_ij_('Cust11',_'Cust46'),
#  ('Cust11', 'Cust47'): y_ij_('Cust11',_'Cust47'),
#  ('Cust11', 'Cust48'): y_ij_('Cust11',_'Cust48'),
#  ('Cust11', 'Cust49'): y_ij_('Cust11',_'Cust49'),
#  ('Cust11', 'Cust50'): y_ij_('Cust11',_'Cust50'),
#  ('Cust12', 'Cust1'): y_ij_('Cust12',_'Cust1'),
#  ('Cust12', 'Cust2'): y_ij_('Cust12',_'Cust2'),
#  ('Cust12', 'Cust3'): y_ij_('Cust12',_'Cust3'),
#  ('Cust12', 'Cust4'): y_ij_('Cust12',_'Cust4'),
#  ('Cust12', 'Cust5'): y_ij_('Cust12',_'Cust5'),
#  ('Cust12', 'Cust6'): y_ij_('Cust12',_'Cust6'),
#  ('Cust12', 'Cust7'): y_ij_('Cust12',_'Cust7'),
#  ('Cust12', 'Cust8'): y_ij_('Cust12',_'Cust8'),
#  ('Cust12', 'Cust9'): y_ij_('Cust12',_'Cust9'),
#  ('Cust12', 'Cust10'): y_ij_('Cust12',_'Cust10'),
#  ('Cust12', 'Cust11'): y_ij_('Cust12',_'Cust11'),
#  ('Cust12', 'Cust12'): y_ij_('Cust12',_'Cust12'),
#  ('Cust12', 'Cust13'): y_ij_('Cust12',_'Cust13'),
#  ('Cust12', 'Cust14'): y_ij_('Cust12',_'Cust14'),
#  ('Cust12', 'Cust15'): y_ij_('Cust12',_'Cust15'),
#  ('Cust12', 'Cust16'): y_ij_('Cust12',_'Cust16'),
#  ('Cust12', 'Cust17'): y_ij_('Cust12',_'Cust17'),
#  ('Cust12', 'Cust18'): y_ij_('Cust12',_'Cust18'),
#  ('Cust12', 'Cust19'): y_ij_('Cust12',_'Cust19'),
#  ('Cust12', 'Cust20'): y_ij_('Cust12',_'Cust20'),
#  ('Cust12', 'Cust21'): y_ij_('Cust12',_'Cust21'),
#  ('Cust12', 'Cust22'): y_ij_('Cust12',_'Cust22'),
#  ('Cust12', 'Cust23'): y_ij_('Cust12',_'Cust23'),
#  ('Cust12', 'Cust24'): y_ij_('Cust12',_'Cust24'),
#  ('Cust12', 'Cust25'): y_ij_('Cust12',_'Cust25'),
#  ('Cust12', 'Cust26'): y_ij_('Cust12',_'Cust26'),
#  ('Cust12', 'Cust27'): y_ij_('Cust12',_'Cust27'),
#  ('Cust12', 'Cust28'): y_ij_('Cust12',_'Cust28'),
#  ('Cust12', 'Cust29'): y_ij_('Cust12',_'Cust29'),
#  ('Cust12', 'Cust30'): y_ij_('Cust12',_'Cust30'),
#  ('Cust12', 'Cust31'): y_ij_('Cust12',_'Cust31'),
#  ('Cust12', 'Cust32'): y_ij_('Cust12',_'Cust32'),
#  ('Cust12', 'Cust33'): y_ij_('Cust12',_'Cust33'),
#  ('Cust12', 'Cust34'): y_ij_('Cust12',_'Cust34'),
#  ('Cust15', 'Cust10'): y_ij_('Cust15',_'Cust10'),
#  ('Cust15', 'Cust11'): y_ij_('Cust15',_'Cust11'),
#  ('Cust15', 'Cust12'): y_ij_('Cust15',_'Cust12'),
#  ('Cust15', 'Cust13'): y_ij_('Cust15',_'Cust13'),
#  ('Cust15', 'Cust14'): y_ij_('Cust15',_'Cust14'),
#  ('Cust15', 'Cust15'): y_ij_('Cust15',_'Cust15'),
#  ('Cust15', 'Cust16'): y_ij_('Cust15',_'Cust16'),
#  ('Cust15', 'Cust17'): y_ij_('Cust15',_'Cust17'),
#  ('Cust15', 'Cust18'): y_ij_('Cust15',_'Cust18'),
#  ('Cust15', 'Cust19'): y_ij_('Cust15',_'Cust19'),
#  ('Cust15', 'Cust20'): y_ij_('Cust15',_'Cust20'),
#  ('Cust15', 'Cust21'): y_ij_('Cust15',_'Cust21'),
#  ('Cust15', 'Cust22'): y_ij_('Cust15',_'Cust22'),
#  ('Cust15', 'Cust23'): y_ij_('Cust15',_'Cust23'),
#  ('Cust15', 'Cust24'): y_ij_('Cust15',_'Cust24'),
#  ('Cust15', 'Cust25'): y_ij_('Cust15',_'Cust25'),
#  ('Cust15', 'Cust26'): y_ij_('Cust15',_'Cust26'),
#  ('Cust15', 'Cust27'): y_ij_('Cust15',_'Cust27'),
#  ('Cust15', 'Cust28'): y_ij_('Cust15',_'Cust28'),
#  ('Cust15', 'Cust29'): y_ij_('Cust15',_'Cust29'),
#  ('Cust15', 'Cust30'): y_ij_('Cust15',_'Cust30'),
#  ('Cust15', 'Cust31'): y_ij_('Cust15',_'Cust31'),
#  ('Cust15', 'Cust32'): y_ij_('Cust15',_'Cust32'),
#  ('Cust15', 'Cust33'): y_ij_('Cust15',_'Cust33'),
#  ('Cust15', 'Cust34'): y_ij_('Cust15',_'Cust34'),
#  ('Cust15', 'Cust35'): y_ij_('Cust15',_'Cust35'),
#  ('Cust15', 'Cust36'): y_ij_('Cust15',_'Cust36'),
#  ('Cust15', 'Cust37'): y_ij_('Cust15',_'Cust37'),
#  ('Cust15', 'Cust38'): y_ij_('Cust15',_'Cust38'),
#  ('Cust15', 'Cust39'): y_ij_('Cust15',_'Cust39'),
#  ('Cust15', 'Cust40'): y_ij_('Cust15',_'Cust40'),
#  ('Cust15', 'Cust41'): y_ij_('Cust15',_'Cust41'),
#  ('Cust15', 'Cust42'): y_ij_('Cust15',_'Cust42'),
#  ('Cust15', 'Cust43'): y_ij_('Cust15',_'Cust43'),
#  ('Cust15', 'Cust44'): y_ij_('Cust15',_'Cust44'),
#  ('Cust15', 'Cust45'): y_ij_('Cust15',_'Cust45'),
#  ('Cust15', 'Cust46'): y_ij_('Cust15',_'Cust46'),
#  ('Cust15', 'Cust47'): y_ij_('Cust15',_'Cust47'),
#  ('Cust15', 'Cust48'): y_ij_('Cust15',_'Cust48'),
#  ('Cust15', 'Cust49'): y_ij_('Cust15',_'Cust49'),
#  ('Cust15', 'Cust50'): y_ij_('Cust15',_'Cust50'),
#  ('Cust16', 'Cust1'): y_ij_('Cust16',_'Cust1'),
#  ('Cust16', 'Cust2'): y_ij_('Cust16',_'Cust2'),
#  ('Cust16', 'Cust3'): y_ij_('Cust16',_'Cust3'),
#  ('Cust16', 'Cust4'): y_ij_('Cust16',_'Cust4'),
#  ('Cust16', 'Cust5'): y_ij_('Cust16',_'Cust5'),
#  ('Cust16', 'Cust6'): y_ij_('Cust16',_'Cust6'),
#  ('Cust16', 'Cust7'): y_ij_('Cust16',_'Cust7'),
#  ('Cust16', 'Cust8'): y_ij_('Cust16',_'Cust8'),
#  ('Cust16', 'Cust9'): y_ij_('Cust16',_'Cust9'),
#  ('Cust16', 'Cust10'): y_ij_('Cust16',_'Cust10'),
#  ('Cust16', 'Cust11'): y_ij_('Cust16',_'Cust11'),
#  ('Cust16', 'Cust12'): y_ij_('Cust16',_'Cust12'),
#  ('Cust16', 'Cust13'): y_ij_('Cust16',_'Cust13'),
#  ('Cust16', 'Cust14'): y_ij_('Cust16',_'Cust14'),
#  ('Cust16', 'Cust15'): y_ij_('Cust16',_'Cust15'),
#  ('Cust16', 'Cust16'): y_ij_('Cust16',_'Cust16'),
#  ('Cust16', 'Cust17'): y_ij_('Cust16',_'Cust17'),
#  ('Cust16', 'Cust18'): y_ij_('Cust16',_'Cust18'),
#  ('Cust16', 'Cust19'): y_ij_('Cust16',_'Cust19'),
#  ('Cust16', 'Cust20'): y_ij_('Cust16',_'Cust20'),
#  ('Cust16', 'Cust21'): y_ij_('Cust16',_'Cust21'),
#  ('Cust16', 'Cust22'): y_ij_('Cust16',_'Cust22'),
#  ('Cust16', 'Cust23'): y_ij_('Cust16',_'Cust23'),
#  ('Cust16', 'Cust24'): y_ij_('Cust16',_'Cust24'),
#  ('Cust16', 'Cust25'): y_ij_('Cust16',_'Cust25'),
#  ('Cust16', 'Cust26'): y_ij_('Cust16',_'Cust26'),
#  ('Cust16', 'Cust27'): y_ij_('Cust16',_'Cust27'),
#  ('Cust16', 'Cust28'): y_ij_('Cust16',_'Cust28'),
#  ('Cust16', 'Cust29'): y_ij_('Cust16',_'Cust29'),
#  ('Cust16', 'Cust30'): y_ij_('Cust16',_'Cust30'),
#  ('Cust16', 'Cust31'): y_ij_('Cust16',_'Cust31'),
#  ('Cust16', 'Cust32'): y_ij_('Cust16',_'Cust32'),
#  ('Cust16', 'Cust33'): y_ij_('Cust16',_'Cust33'),
#  ('Cust16', 'Cust34'): y_ij_('Cust16',_'Cust34'),
#  ('Cust16', 'Cust35'): y_ij_('Cust16',_'Cust35'),
#  ('Cust16', 'Cust36'): y_ij_('Cust16',_'Cust36'),
#  ('Cust16', 'Cust37'): y_ij_('Cust16',_'Cust37'),
#  ('Cust16', 'Cust38'): y_ij_('Cust16',_'Cust38'),
#  ('Cust16', 'Cust39'): y_ij_('Cust16',_'Cust39'),
#  ('Cust16', 'Cust40'): y_ij_('Cust16',_'Cust40'),
#  ('Cust16', 'Cust41'): y_ij_('Cust16',_'Cust41'),
#  ('Cust16', 'Cust42'): y_ij_('Cust16',_'Cust42'),
#  ('Cust16', 'Cust43'): y_ij_('Cust16',_'Cust43'),
#  ('Cust16', 'Cust44'): y_ij_('Cust16',_'Cust44'),
#  ('Cust16', 'Cust45'): y_ij_('Cust16',_'Cust45'),
#  ('Cust16', 'Cust46'): y_ij_('Cust16',_'Cust46'),
#  ('Cust16', 'Cust47'): y_ij_('Cust16',_'Cust47'),
#  ('Cust16', 'Cust48'): y_ij_('Cust16',_'Cust48'),
#  ('Cust16', 'Cust49'): y_ij_('Cust16',_'Cust49'),
#  ('Cust16', 'Cust50'): y_ij_('Cust16',_'Cust50'),
#  ('Cust17', 'Cust1'): y_ij_('Cust17',_'Cust1'),
#  ('Cust17', 'Cust2'): y_ij_('Cust17',_'Cust2'),
#  ('Cust17', 'Cust3'): y_ij_('Cust17',_'Cust3'),
#  ('Cust17', 'Cust4'): y_ij_('Cust17',_'Cust4'),
#  ('Cust17', 'Cust5'): y_ij_('Cust17',_'Cust5'),
#  ('Cust17', 'Cust6'): y_ij_('Cust17',_'Cust6'),
#  ('Cust17', 'Cust7'): y_ij_('Cust17',_'Cust7'),
#  ('Cust17', 'Cust8'): y_ij_('Cust17',_'Cust8'),
#  ('Cust17', 'Cust9'): y_ij_('Cust17',_'Cust9'),
#  ('Cust17', 'Cust10'): y_ij_('Cust17',_'Cust10'),
#  ('Cust17', 'Cust11'): y_ij_('Cust17',_'Cust11'),
#  ('Cust17', 'Cust12'): y_ij_('Cust17',_'Cust12'),
#  ('Cust17', 'Cust13'): y_ij_('Cust17',_'Cust13'),
#  ('Cust17', 'Cust14'): y_ij_('Cust17',_'Cust14'),
#  ('Cust17', 'Cust15'): y_ij_('Cust17',_'Cust15'),
#  ('Cust17', 'Cust16'): y_ij_('Cust17',_'Cust16'),
#  ('Cust17', 'Cust17'): y_ij_('Cust17',_'Cust17'),
#  ('Cust17', 'Cust18'): y_ij_('Cust17',_'Cust18'),
#  ('Cust17', 'Cust19'): y_ij_('Cust17',_'Cust19'),
#  ('Cust17', 'Cust20'): y_ij_('Cust17',_'Cust20'),
#  ('Cust17', 'Cust21'): y_ij_('Cust17',_'Cust21'),
#  ('Cust17', 'Cust22'): y_ij_('Cust17',_'Cust22'),
#  ('Cust17', 'Cust23'): y_ij_('Cust17',_'Cust23'),
#  ('Cust17', 'Cust24'): y_ij_('Cust17',_'Cust24'),
#  ('Cust17', 'Cust25'): y_ij_('Cust17',_'Cust25'),
#  ('Cust17', 'Cust26'): y_ij_('Cust17',_'Cust26'),
#  ('Cust17', 'Cust27'): y_ij_('Cust17',_'Cust27'),
#  ('Cust17', 'Cust28'): y_ij_('Cust17',_'Cust28'),
#  ('Cust17', 'Cust29'): y_ij_('Cust17',_'Cust29'),
#  ('Cust17', 'Cust30'): y_ij_('Cust17',_'Cust30'),
#  ('Cust17', 'Cust31'): y_ij_('Cust17',_'Cust31'),
#  ('Cust17', 'Cust32'): y_ij_('Cust17',_'Cust32'),
#  ('Cust17', 'Cust33'): y_ij_('Cust17',_'Cust33'),
#  ('Cust17', 'Cust34'): y_ij_('Cust17',_'Cust34'),
